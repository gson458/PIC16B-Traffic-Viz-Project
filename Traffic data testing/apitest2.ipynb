# %%
import requests
import pandas as pd
import credentials as cred

# %%
key=cred.mapquest_api_key
bbox="39.95,-105.25,39.52,-104.71"
bbox="40,-122,39,-121"
response = requests.get(f"https://www.mapquestapi.com/traffic/v2/incidents?key={key}&boundingBox={bbox}&filters=construction,incidents")

# %%
response.json().keys()
df = pd.DataFrame(response.json()["incidents"])
df
# Out:
#                      id  type  severity  eventCode       lat        lng
# 0    727644382194048314     1         1        803  39.74199 -121.79185  \
# 1    608077249452275769     1         1        803  39.51694 -121.01098
# 2   4152078556626395042     1         1        803  39.82262 -121.92122
# 3   4592318362905238148     1         1        803  39.82146 -121.92411
# 4   1476600228324287985     1         1        803  39.94842 -121.65215
# 5   2171515694081614803     1         2        701  40.03849 -120.98408
# 6    908863357339057331     1         1        803  39.50522 -121.02053
# 7   2825758622211053762     4         3        401  39.07159 -121.44306
# 8    115761922494613541     4         3        401  39.81278 -121.57842
# 9   1758831610184079638     1         3        701  39.96110 -121.28121
# 10  2702641940470657641     1         1        803  39.46179 -121.99238
# 11  4617214990963528066     1         3        701  39.76289 -121.46592
# 12   731457236846205230     4         3        401  39.80044 -121.58088
# 13  4190109439083829911     4         3        401  39.79423 -121.45300
# 14  2600782410370498792     1         1        802  39.17099 -121.59002
#
#               startTime              endTime  impacting
# 0   2023-05-09T03:01:34  2023-05-09T13:01:34       True  \
# 1   2023-02-13T15:01:00  2023-06-02T01:01:00       True
# 2   2023-05-09T04:30:00  2023-05-09T13:01:00       True
# 3   2023-05-09T04:30:00  2023-05-09T13:01:00       True
# 4   2022-05-05T14:01:00  2023-06-01T00:01:00       True
# 5   2023-05-08T19:14:42  2023-05-09T23:44:42       True
# 6   2023-02-13T15:01:00  2023-06-02T01:01:00       True
# 7   2023-05-08T17:21:38  2023-05-10T05:21:38       True
# 8   2023-05-08T15:04:48  2023-05-10T03:04:48       True
# 9   2023-05-08T21:38:15  2023-05-09T09:38:15       True
# 10  2022-05-05T07:00:00  2023-05-13T01:59:53       True
# 11  2023-05-08T19:22:12  2023-05-09T09:22:12       True
# 12  2023-05-08T23:11:45  2023-05-10T05:11:45       True
# 13  2023-05-07T20:14:41  2023-05-10T04:14:41       True
# 14  2022-04-18T07:00:00  2023-05-13T01:59:53       True
#
#                       shortDesc
# 0             Construction work  \
# 1             Construction work
# 2             Construction work
# 3             Construction work
# 4             Construction work
# 5             Road construction
# 6             Construction work
# 7                        Closed
# 8                        Closed
# 9             Road construction
# 10            Construction work
# 11            Road construction
# 12                       Closed
# 13                       Closed
# 14  Long-term road construction
#
#                                              fullDesc  delayFromFreeFlow
# 0                   At Bruce Road - Construction work                  0  \
# 1                At Oak Valley Rd - Construction work                  0
# 2                  At Meridian Rd - Construction work                  0
# 3                                   Construction work                  0
# 4                    At F Line Rd - Construction work                  0
# 5   Between CA-89 (South) and Old Utah Constructio...                  0
# 6      At North Yuba River Bridge - Construction work                  0
# 7                             At Virginia Rd - Closed                  0
# 8                                              Closed                  0
# 9   Between Andy Mountain Rd/Rim Rd/Deadwood Rd an...                  0
# 10  At CA-45/County Road 61/Riz Rd - Construction ...                  0
# 11  At Andy Mountain Rd/Rim Rd/Deadwood Rd - Road ...                  0
# 12                                             Closed                  0
# 13  Between Pentz Rd and North Fork Feather River ...                  0
# 14  Between CA-20/12th St and Lower Honcut Rd - Lo...                  0
#
#     delayFromTypical   distance
# 0                  0   0.053449  \
# 1                  0   1.057800
# 2                  0   0.173400
# 3                  0   0.173400
# 4                  0   2.098198
# 5                  0  43.023617
# 6                  0   1.082660
# 7                  0   1.362337
# 8                  0   0.047856
# 9                  0  23.242387
# 10                 0   0.075202
# 11                 0   2.704786
# 12                 0   0.894966
# 13                 0  16.915475
# 14                 0   9.641392
#
#                                              iconURL parameterizedDescription
# 0   http://content.mqcdn.com/mqtraffic/const_min.png                       {}
# 1   http://content.mqcdn.com/mqtraffic/const_min.png                       {}
# 2   http://content.mqcdn.com/mqtraffic/const_min.png                       {}
# 3   http://content.mqcdn.com/mqtraffic/const_min.png                       {}
# 4   http://content.mqcdn.com/mqtraffic/const_min.png                       {}
# 5   http://content.mqcdn.com/mqtraffic/const_mod.png                       {}
# 6   http://content.mqcdn.com/mqtraffic/const_min.png                       {}
# 7   http://content.mqcdn.com/mqtraffic/incid_sev.png                       {}
# 8   http://content.mqcdn.com/mqtraffic/incid_sev.png                       {}
# 9   http://content.mqcdn.com/mqtraffic/const_sev.png                       {}
# 10  http://content.mqcdn.com/mqtraffic/const_min.png                       {}
# 11  http://content.mqcdn.com/mqtraffic/const_sev.png                       {}
# 12  http://content.mqcdn.com/mqtraffic/incid_sev.png                       {}
# 13  http://content.mqcdn.com/mqtraffic/incid_sev.png                       {}
# 14  http://content.mqcdn.com/mqtraffic/const_min.png                       {}

# %%
traffic = requests.get(f"https://www.mapquestapi.com/traffic/v2/flow?key={key}&mapLat=38.890763&mapLng=-77.084755&mapHeight=400&mapWidth=400&mapScale=108335")

# %%
import gmaps
import gmaps.datasets
key="key"

# %%
# Get the dataset
earthquake_df = gmaps.datasets.load_dataset_as_df('earthquakes')#Get the locations from the data set
locations = earthquake_df[['latitude', 'longitude']]#Get the magnitude from the data
weights = earthquake_df['magnitude']#Set up your map
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
